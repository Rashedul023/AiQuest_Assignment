# %% [markdown]
# #### Preprocess the housing dataset by encoding all categorical variables using appropriate techniques. Ensure the final dataset is fully numeric and ready for machine learning analysis. y = SalePrice.

# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
dataframe = pd.read_csv('house.csv')
dataframe.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df = dataframe.copy()
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df = df.drop(['Alley','MasVnrType','FireplaceQu','PoolQC','Fence','MiscFeature'], axis=1)
df
#I have droped this columns because of too much null values
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
df = df.drop('Utilities',axis=1)
df.head()
#I have droped this because all of them are same value
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl  ...             0         0           0        0
# 1       FR2       Gtl  ...             0         0           0        0
# 2    Inside       Gtl  ...             0         0           0        0
# 3    Corner       Gtl  ...           272         0           0        0
# 4       FR2       Gtl  ...             0         0           0        0
#
#   MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
categorical_columns = df.select_dtypes('object').columns
categorical_columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
for c in categorical_columns:
    if c == 'SaleType' or c == 'Exterior1st' or c=='Exterior2nd' or c== 'Neighborhood':
        continue #I will use binary encoding for these columns
    elif c=='LotConfig':
        continue #I will use one hot encoding for this column
    df[c] = le.fit_transform(df[[c]])

df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour LotConfig  LandSlope  ... EnclosedPorch  3SsnPorch  \
# 0            3    Inside          0  ...             0          0
# 1            3       FR2          0  ...             0          0
# 2            3    Inside          0  ...             0          0
# 3            3    Corner          0  ...           272          0
# 4            3       FR2          0  ...             0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# 0            0         0        0       2    2008        WD              4
# ...

# %%
import category_encoders as ce
BinEn = ce.BinaryEncoder(cols=['SaleType','Exterior1st', 'Exterior2nd', 'Neighborhood'])
BinEn
# Out:
# BinaryEncoder(cols=['SaleType', 'Exterior1st', 'Exterior2nd', 'Neighborhood'])

# %%
df = BinEn.fit_transform(df)
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour LotConfig  LandSlope  ...  PoolArea  MiscVal  MoSold  YrSold  \
# 0            3    Inside          0  ...         0        0       2    2008
# 1            3       FR2          0  ...         0        0       5    2007
# 2            3    Inside          0  ...         0        0       9    2008
# 3            3    Corner          0  ...         0        0       2    2006
# 4            3       FR2          0  ...         0        0      12    2008
#
#    SaleType_0  SaleType_1  SaleType_2  SaleType_3  SaleCondition  SalePrice
# ...

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
lb = LabelBinarizer()
area_encoded = lb.fit_transform(df['LotConfig'])

area_encoded_df = pd.DataFrame(area_encoded, columns=lb.classes_)
area_encoded_df.head()
# Out:
#    Corner  CulDSac  FR2  FR3  Inside
# 0       0        0    0    0       1
# 1       0        0    1    0       0
# 2       0        0    0    0       1
# 3       1        0    0    0       0
# 4       0        0    1    0       0

# %%
area_encoded_df = area_encoded_df.drop(columns=lb.classes_[0])
area_encoded_df.head()
# Out:
#    CulDSac  FR2  FR3  Inside
# 0        0    0    0       1
# 1        0    1    0       0
# 2        0    0    0       1
# 3        0    0    0       0
# 4        0    1    0       0

# %%
df = pd.concat([df.drop('LotConfig', axis=1), area_encoded_df], axis=1)
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  LandSlope  Neighborhood_0  ...  SaleType_0  SaleType_1  \
# 0            3          0               0  ...           0           0
# 1            3          0               0  ...           0           0
# 2            3          0               0  ...           0           0
# 3            3          0               0  ...           0           0
# 4            3          0               0  ...           0           0
#
#    SaleType_2  SaleType_3  SaleCondition  SalePrice  CulDSac  FR2  FR3  Inside
# ...

# %% [markdown]
# ## Filling null values with median

# %%
columns_with_nulls = df.columns[df.isna().any()]
columns_with_nulls
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'GarageYrBlt'], dtype='object')

# %%
for col in columns_with_nulls:
    med = df[col].median()
    df[col] = df[col].fillna(med)

df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  LandSlope  Neighborhood_0  ...  SaleType_0  SaleType_1  \
# 0            3          0               0  ...           0           0
# 1            3          0               0  ...           0           0
# 2            3          0               0  ...           0           0
# 3            3          0               0  ...           0           0
# 4            3          0               0  ...           0           0
#
#    SaleType_2  SaleType_3  SaleCondition  SalePrice  CulDSac  FR2  FR3  Inside
# ...

# %%
df2 = df['SalePrice']
df2.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
df = df.drop("SalePrice",axis=1)
df = pd.concat([df,df2],axis=1)
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  LandSlope  Neighborhood_0  ...  SaleType_0  SaleType_1  \
# 0            3          0               0  ...           0           0
# 1            3          0               0  ...           0           0
# 2            3          0               0  ...           0           0
# 3            3          0               0  ...           0           0
# 4            3          0               0  ...           0           0
#
#    SaleType_2  SaleType_3  SaleCondition  CulDSac  FR2  FR3  Inside  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 91 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              1460 non-null   int64
#  1   MSSubClass      1460 non-null   int64
#  2   MSZoning        1460 non-null   int32
#  3   LotFrontage     1460 non-null   float64
#  4   LotArea         1460 non-null   int64
#  5   Street          1460 non-null   int32
#  6   LotShape        1460 non-null   int32
#  7   LandContour     1460 non-null   int32
#  8   LandSlope       1460 non-null   int32
#  9   Neighborhood_0  1460 non-null   int64
#  10  Neighborhood_1  1460 non-null   int64
#  11  Neighborhood_2  1460 non-null   int64
#  12  Neighborhood_3  1460 non-null   int64
#  13  Neighborhood_4  1460 non-null   int64
#  14  Condition1      1460 non-null   int32
#  15  Condition2      1460 non-null   int32
#  16  BldgType        1460 non-null   int32
# ...

# %%
X = df.iloc[:, :-1]
X
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1          60         3         65.0     8450       1         3
# 1        2          20         3         80.0     9600       1         3
# 2        3          60         3         68.0    11250       1         0
# 3        4          70         3         60.0     9550       1         0
# 4        5          60         3         84.0    14260       1         0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1455  1456          60         3         62.0     7917       1         3
# 1456  1457          20         3         85.0    13175       1         3
# 1457  1458          70         3         66.0     9042       1         3
# 1458  1459          20         3         68.0     9717       1         3
# 1459  1460          20         3         75.0     9937       1         3
#
#       LandContour  LandSlope  Neighborhood_0  ...  YrSold  SaleType_0  \
# ...

# %%
Y = df['SalePrice']
Y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
reg.score(X,Y)
#For all level encoder This result was 0.84
# Out:
# 0.8542728492695149

# %%
df.to_csv('answer.csv')
